# %% [markdown]
# # logistic regressionを使ったクラス分類コード

# %%
import pandas as pd
df = pd.read_csv("test_class.txt", sep="\t")

# %%
x=df.loc[:, ['Nucleus: Area µm^2',
       'Nucleus: Length µm', 'Nucleus: Circularity', 'Nucleus: Solidity',
       'Nucleus: Max diameter µm', 'Nucleus: Min diameter µm',
       'Cell: Area µm^2', 'Cell: Length µm', 'Cell: Circularity',
       'Cell: Solidity', 'Cell: Max diameter µm', 'Cell: Min diameter µm',
       'Nucleus/Cell area ratio', 'Hematoxylin: Nucleus: Mean',
       'Hematoxylin: Nucleus: Median', 'Hematoxylin: Nucleus: Min',
       'Hematoxylin: Nucleus: Max', 'Hematoxylin: Nucleus: Std.Dev.',
       'Hematoxylin: Cytoplasm: Mean', 'Hematoxylin: Cytoplasm: Median',
       'Hematoxylin: Cytoplasm: Min', 'Hematoxylin: Cytoplasm: Max',
       'Hematoxylin: Cytoplasm: Std.Dev.', 'Hematoxylin: Membrane: Mean',
       'Hematoxylin: Membrane: Median', 'Hematoxylin: Membrane: Min',
       'Hematoxylin: Membrane: Max', 'Hematoxylin: Membrane: Std.Dev.',
       'Hematoxylin: Cell: Mean', 'Hematoxylin: Cell: Median',
       'Hematoxylin: Cell: Min', 'Hematoxylin: Cell: Max',
       'Hematoxylin: Cell: Std.Dev.', 'Eosin: Nucleus: Mean',
       'Eosin: Nucleus: Median', 'Eosin: Nucleus: Min', 'Eosin: Nucleus: Max',
       'Eosin: Nucleus: Std.Dev.', 'Eosin: Cytoplasm: Mean',
       'Eosin: Cytoplasm: Median', 'Eosin: Cytoplasm: Min',
       'Eosin: Cytoplasm: Max', 'Eosin: Cytoplasm: Std.Dev.',
       'Eosin: Membrane: Mean', 'Eosin: Membrane: Median',
       'Eosin: Membrane: Min', 'Eosin: Membrane: Max',
       'Eosin: Membrane: Std.Dev.', 'Eosin: Cell: Mean', 'Eosin: Cell: Median',
       'Eosin: Cell: Min', 'Eosin: Cell: Max', 'Eosin: Cell: Std.Dev.']]
y=df.loc[:, "Parent"]

# %%
y.value_counts()
# Out:
# Tumor           4600
# Immune cells    4003
# Other           1447
# Name: Parent, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
Scaler = StandardScaler()
x_std = Scaler.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x_std, y, random_state=0)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(max_iter=1000).fit(X_train, y_train)
print(model.score(X_test, y_test))
# Out:
# 0.8869876641464385

# %%
features = x.columns

# %%
coef = model.coef_[0]

# %%
model.coef_[0]
# Out:
# array([-1.1281094 , -0.41906012,  0.13832574,  0.37793425, -0.55791696,
#        -1.25230737,  1.79921839, -0.1821996 ,  0.0223514 , -0.58413029,
#        -0.12449525,  0.06691045, -0.13552968,  0.26985566, -0.28756824,
#        -0.17440016,  0.83353584, -0.55674626, -0.805709  ,  0.34045607,
#         0.48578978,  0.15075391,  0.41671874,  0.23406509, -0.03386367,
#        -0.45078314, -0.02834598,  0.13776112, -0.25173576,  0.52969824,
#        -0.17883693, -0.283816  ,  0.47854928, -0.12059319, -0.19798155,
#         0.08023782, -0.01138393,  0.52423041,  0.71225851,  0.02028027,
#        -0.15319975,  0.15035424,  0.20810756, -1.17733284, -0.24751513,
#         0.15973352, -0.11883098,  0.14909008,  0.00519058,  0.00738436,
#         0.18607354,  0.29646496, -1.28660445])

# %%
print("intercept: ", model.intercept_)
# Out:
# intercept:  [ 0.61865762 -1.84068463  1.22202701]

# %%
df = pd.DataFrame([features, coef]).T

# %%
df.columns = ["features", "coef"]

# %%
df.sort_values(by="coef", ascending=False)
# Out:
#                             features      coef
# 6                    Cell: Area µm^2  1.799218
# 16         Hematoxylin: Nucleus: Max  0.833536
# 38            Eosin: Cytoplasm: Mean  0.712259
# 29         Hematoxylin: Cell: Median  0.529698
# 37          Eosin: Nucleus: Std.Dev.   0.52423
# 20       Hematoxylin: Cytoplasm: Min   0.48579
# 32       Hematoxylin: Cell: Std.Dev.  0.478549
# 22  Hematoxylin: Cytoplasm: Std.Dev.  0.416719
# 3                  Nucleus: Solidity  0.377934
# 19    Hematoxylin: Cytoplasm: Median  0.340456
# 51                  Eosin: Cell: Max  0.296465
# 13        Hematoxylin: Nucleus: Mean  0.269856
# 23       Hematoxylin: Membrane: Mean  0.234065
# 42        Eosin: Cytoplasm: Std.Dev.  0.208108
# 50                  Eosin: Cell: Min  0.186074
# 45              Eosin: Membrane: Min  0.159734
# 21       Hematoxylin: Cytoplasm: Max  0.150754
# 41             Eosin: Cytoplasm: Max  0.150354
# 47         Eosin: Membrane: Std.Dev.   0.14909
# 2               Nucleus: Circularity  0.138326
# 27   Hematoxylin: Membrane: Std.Dev.  0.137761
# 35               Eosin: Nucleus: Min  0.080238
# 11             Cell: Min diameter µm   0.06691
# 8                  Cell: Circularity  0.022351
# 39          Eosin: Cytoplasm: Median   0.02028
# 49               Eosin: Cell: Median  0.007384
# 48                 Eosin: Cell: Mean  0.005191
# 36               Eosin: Nucleus: Max -0.011384
# 26        Hematoxylin: Membrane: Max -0.028346
# 24     Hematoxylin: Membrane: Median -0.033864
# 46              Eosin: Membrane: Max -0.118831
# 33              Eosin: Nucleus: Mean -0.120593
# 10             Cell: Max diameter µm -0.124495
# 12           Nucleus/Cell area ratio  -0.13553
# 40             Eosin: Cytoplasm: Min   -0.1532
# 15         Hematoxylin: Nucleus: Min   -0.1744
# 30            Hematoxylin: Cell: Min -0.178837
# 7                    Cell: Length µm   -0.1822
# 34            Eosin: Nucleus: Median -0.197982
# 44           Eosin: Membrane: Median -0.247515
# 28           Hematoxylin: Cell: Mean -0.251736
# 31            Hematoxylin: Cell: Max -0.283816
# 14      Hematoxylin: Nucleus: Median -0.287568
# 1                 Nucleus: Length µm  -0.41906
# 25        Hematoxylin: Membrane: Min -0.450783
# 17    Hematoxylin: Nucleus: Std.Dev. -0.556746
# 4           Nucleus: Max diameter µm -0.557917
# 9                     Cell: Solidity  -0.58413
# 18      Hematoxylin: Cytoplasm: Mean -0.805709
# 0                 Nucleus: Area µm^2 -1.128109
# 43             Eosin: Membrane: Mean -1.177333
# 5           Nucleus: Min diameter µm -1.252307
# 52             Eosin: Cell: Std.Dev. -1.286604
